# %% [markdown]
# # Heat Map

# %% [markdown]
# ## Grid

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.linspace(-1,1, 100)
y = np.linspace(-1, 1, 100)
X, Y = np.meshgrid(x, y)
#print (X)
#print("--------")
#print(Y)

# %% [markdown]
# ## function for heatmap

# %% [markdown]
# #### the function for heat map is
# $Z=e−(x2+y2)cos⁡(4x)+tanh⁡(xy)+x3e−y2$

# %%
Z= np.exp(-(X**2 + Y**2)) * np.cos(4 * X) + np.tanh(X * Y) + X**3 * np.exp(-Y**2)

# %%
plt.figure(figsize=(12, 9))
sns.heatmap(Z, cmap='viridis', xticklabels=30, yticklabels=20, 
            cbar=True, cbar_kws={'label': 'Z Value', 'shrink': 0.6})
#plt.title("Heatmap of Complex Function", fontsize=16, pad=20)
#plt.xlabel("X", fontsize=12)
#plt.ylabel("Y", fontsize=12)
#plt.xticks(np.arange(-1, 1, 40), [f"{val:.1f}" for val in x[::40]], rotation=45)
#plt.yticks(np.arange(-1, 1, 40), [f"{val:.1f}" for val in y[::40]])
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 7
#       5 plt.xlabel("X", fontsize=12)
#       6 plt.ylabel("Y", fontsize=12)
# ----> 7 plt.xticks(np.arange(-1, 1, 40), [f"{val:.1f}" for val in x[::40]], rotation=45)
#       8 plt.yticks(np.arange(-1, 1, 40), [f"{val:.1f}" for val in y[::40]])
#       9 plt.tight_layout()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:2239, in xticks(ticks, labels, minor, **kwargs)
#    2237         l._internal_update(kwargs)
#    2238 else:
# -> 2239     labels_out = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    2241 return locs, labels_out
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ...
